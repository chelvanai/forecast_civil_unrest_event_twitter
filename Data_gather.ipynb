# %% [markdown]
# ### Twitter data gather, here used tweepy to get data from twitter

# %%
import tweepy as tw
import csv
import pandas as pd

# %% [markdown]
# ### get twitter access key to get data.

# %%
consumer_key= '*****'
consumer_secret= '*****'
access_token= '*****'
access_token_secret= '*****'

# %%
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
csvFile = open('srilanka.csv', 'a')
csvWriter = csv.writer(csvFile)

# %%
for tweet in tw.Cursor(api.search,q="#SriLanka",count=100,lang="en",since="2019-07-09").items():
    print (tweet.created_at, tweet.text)
    csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8')])
# Out:
# 2019-07-09 14:40:24 RT @SriLankaTweet: Landmark for healthcare services in #SriLanka 🇱🇰!
# World Health Organization (WHO) declared Sri Lanka as a
# ✔️Measles-Fre…
# 2019-07-09 14:35:31 RT @DonsDotLK: Beenuka &amp; Malki!
# ©Don's 2019 | +94715964643
# All Rights Reserved.
# .
# .
# .
# #weddings #srilanka #photographer #canon #sigma #tamr…
# 2019-07-09 14:35:17 RT @DonsDotLK: Riyon's Family Portrait Session!
# ©Don's 2019 | +94715964643
# .
# .
# .
# .
# .
# #Kiddies #birthday #party #lifestyle #photographer #ca…
# 2019-07-09 14:35:03 Riyon's Family Portrait Session!
# ©Don's 2019 | +94715964643
# .
# .
# .
# .
# .
# #Kiddies #birthday #party #lifestyle… https://t.co/TQyP1BG50F
# 2019-07-09 14:33:35 RT @WHOSEARO: #GREATNEWS: #SriLanka 🇱🇰 has eliminated #measles!
#
# The country has interrupted transmission of the indigenous virus that caus…
# 2019-07-09 14:33:14 RT @WHOSEARO: #GREATNEWS: #SriLanka 🇱🇰 has eliminated #measles!
#
# ...
